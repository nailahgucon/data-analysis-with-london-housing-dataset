# %% [markdown]
# # Data Analysis with Python using Pandas dataframe: London Housing Dataset

# %% [markdown]
# #### Objectives:
#
# 1. `Convert the data type of 'Date' column to date-time format.`
#
# 2. `Add a new column 'year' in the dataframe which contains years only.`
#
# 3. `To add a month as a new column, between date and area columns.`
#
# 4. `Remove the columns year and month from the dataframe.`
#
# 5. `Show all the records where 'No of crimes' are zero and how many such records are there?`
#
# 6. `What is the maximum and minimum 'average_price' per year in England?`
#
# 7. `What is the maximum and minimum no of crimes recorded area?`
#
# 8. `Show the total count of records of each area, where average price is less than 100000.`

# %%
import pandas as pd

# %%
housing_df = pd.read_csv("london-housing-data.csv")

# %%
housing_df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# ## 1. Convert the data type of 'Date' column to date-time format.

# %%
housing_df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
housing_df.date = pd.to_datetime(housing_df.date)

# %%
housing_df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# ## 2. Add a new column 'year' in the dataframe which contains years only.

# %%
housing_df['year'] = housing_df.date.dt.year

# %%
housing_df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %% [markdown]
# #### Extra:

# %% [markdown]
# #### Rearrange the sequence of the columns to start with the 'year' column

# %%
housing_df = housing_df.reindex(columns=['year','date','area','average_price','code','houses_sold','no_of_crimes'])

# %%
housing_df
# Out:
#        year       date            area  average_price       code  houses_sold  \
# 0      1995 1995-01-01  city of london          91449  E09000001         17.0
# 1      1995 1995-02-01  city of london          82203  E09000001          7.0
# 2      1995 1995-03-01  city of london          79121  E09000001         14.0
# 3      1995 1995-04-01  city of london          77101  E09000001          7.0
# 4      1995 1995-05-01  city of london          84409  E09000001         10.0
# ...     ...        ...             ...            ...        ...          ...
# 13544  2019 2019-09-01         england         249942  E92000001      64605.0
# 13545  2019 2019-10-01         england         249376  E92000001      68677.0
# 13546  2019 2019-11-01         england         248515  E92000001      67814.0
# 13547  2019 2019-12-01         england         250410  E92000001          NaN
# 13548  2020 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# ...

# %% [markdown]
# #### Alternatively...

# %%
# reapply year to the end
housing_df.drop(['year'], axis=1, inplace = True)
housing_df['year'] = housing_df.date.dt.year
housing_df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
cols = housing_df.columns.tolist()
cols
# Out:
# ['date',
#  'area',
#  'average_price',
#  'code',
#  'houses_sold',
#  'no_of_crimes',
#  'year']

# %%
# move the last element to the first position
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['year',
#  'date',
#  'area',
#  'average_price',
#  'code',
#  'houses_sold',
#  'no_of_crimes']

# %%
housing_df = housing_df[cols]
housing_df
# Out:
#        year       date            area  average_price       code  houses_sold  \
# 0      1995 1995-01-01  city of london          91449  E09000001         17.0
# 1      1995 1995-02-01  city of london          82203  E09000001          7.0
# 2      1995 1995-03-01  city of london          79121  E09000001         14.0
# 3      1995 1995-04-01  city of london          77101  E09000001          7.0
# 4      1995 1995-05-01  city of london          84409  E09000001         10.0
# ...     ...        ...             ...            ...        ...          ...
# 13544  2019 2019-09-01         england         249942  E92000001      64605.0
# 13545  2019 2019-10-01         england         249376  E92000001      68677.0
# 13546  2019 2019-11-01         england         248515  E92000001      67814.0
# 13547  2019 2019-12-01         england         250410  E92000001          NaN
# 13548  2020 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# ...

# %% [markdown]
# #### Alternatively...

# %%
# reapply year to the end
housing_df.drop(['year'], axis=1, inplace = True)
housing_df['year'] = housing_df.date.dt.year
housing_df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
housing_df.insert(0, 'year_temp', housing_df['year']) 
housing_df.head()
# Out:
#    year_temp       date            area  average_price       code  \
# 0       1995 1995-01-01  city of london          91449  E09000001
# 1       1995 1995-02-01  city of london          82203  E09000001
# 2       1995 1995-03-01  city of london          79121  E09000001
# 3       1995 1995-04-01  city of london          77101  E09000001
# 4       1995 1995-05-01  city of london          84409  E09000001
#
#    houses_sold  no_of_crimes  year
# 0         17.0           NaN  1995
# 1          7.0           NaN  1995
# 2         14.0           NaN  1995
# 3          7.0           NaN  1995
# 4         10.0           NaN  1995

# %%
housing_df.drop('year', axis=1, inplace=True) 
housing_df.head()
# Out:
#    year_temp       date            area  average_price       code  \
# 0       1995 1995-01-01  city of london          91449  E09000001
# 1       1995 1995-02-01  city of london          82203  E09000001
# 2       1995 1995-03-01  city of london          79121  E09000001
# 3       1995 1995-04-01  city of london          77101  E09000001
# 4       1995 1995-05-01  city of london          84409  E09000001
#
#    houses_sold  no_of_crimes
# 0         17.0           NaN
# 1          7.0           NaN
# 2         14.0           NaN
# 3          7.0           NaN
# 4         10.0           NaN

# %%
housing_df.rename(columns={'year_temp': 'year'}, inplace=True)
housing_df.head()
# Out:
#    year       date            area  average_price       code  houses_sold  \
# 0  1995 1995-01-01  city of london          91449  E09000001         17.0
# 1  1995 1995-02-01  city of london          82203  E09000001          7.0
# 2  1995 1995-03-01  city of london          79121  E09000001         14.0
# 3  1995 1995-04-01  city of london          77101  E09000001          7.0
# 4  1995 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## 3. To add a month as a new column, between date and area columns.

# %%
housing_df.head()
# Out:
#    year       date            area  average_price       code  houses_sold  \
# 0  1995 1995-01-01  city of london          91449  E09000001         17.0
# 1  1995 1995-02-01  city of london          82203  E09000001          7.0
# 2  1995 1995-03-01  city of london          79121  E09000001         14.0
# 3  1995 1995-04-01  city of london          77101  E09000001          7.0
# 4  1995 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
housing_df.insert(1, 'month', housing_df.date.dt.month)

# %%
housing_df
# Out:
#        year  month       date            area  average_price       code  \
# 0      1995      1 1995-01-01  city of london          91449  E09000001
# 1      1995      2 1995-02-01  city of london          82203  E09000001
# 2      1995      3 1995-03-01  city of london          79121  E09000001
# 3      1995      4 1995-04-01  city of london          77101  E09000001
# 4      1995      5 1995-05-01  city of london          84409  E09000001
# ...     ...    ...        ...             ...            ...        ...
# 13544  2019      9 2019-09-01         england         249942  E92000001
# 13545  2019     10 2019-10-01         england         249376  E92000001
# 13546  2019     11 2019-11-01         england         248515  E92000001
# 13547  2019     12 2019-12-01         england         250410  E92000001
# 13548  2020      1 2020-01-01         england         247355  E92000001
#
#        houses_sold  no_of_crimes
# 0             17.0           NaN
# 1              7.0           NaN
# ...

# %% [markdown]
# ## 4. Remove the columns year and month from the dataframe.

# %%
housing_df.drop(['year','month'], axis=1, inplace = True)

# %%
housing_df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# ## 5. Show all the records where 'No of crimes' are zero and how many such records are there?

# %%
housing_df[housing_df.no_of_crimes == 0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(housing_df[housing_df.no_of_crimes == 0])
# Out:
# 104

# %% [markdown]
# #### Extra:

# %% [markdown]
# #### What can you tell about how the no_of_crimes affect other factors such as houses_sold and average_price?

# %%
housing_df.plot(x="no_of_crimes", y="houses_sold", kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### More houses were sold where the least amount of crime occured.

# %%
housing_df.plot(x="no_of_crimes", y="average_price", kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### The lesser the crime occuring, the more expensive the house

# %% [markdown]
# ## 6. What is the maximum and minimum 'average_price' per year in England?

# %%
housing_df['year'] = housing_df.date.dt.year

# %%
housing_df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
england_housing_df = housing_df[housing_df.area == 'england']

# %%
england_housing_df
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
england_housing_df.groupby('year').average_price.max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
england_housing_df.groupby('year').average_price.mean()
# Out:
# year
# 1995     53322.416667
# 1996     54151.500000
# 1997     59160.666667
# 1998     64301.666667
# 1999     70070.750000
# 2000     80814.333333
# 2001     90306.750000
# 2002    107981.500000
# 2003    130218.583333
# 2004    152314.416667
# 2005    163570.000000
# 2006    174351.500000
# 2007    190025.583333
# 2008    182379.916667
# 2009    166558.666667
# 2010    177472.666667
# 2011    175230.000000
# 2012    177488.000000
# 2013    182581.416667
# 2014    197771.083333
# 2015    211174.750000
# 2016    227337.166667
# 2017    238161.166667
# 2018    245018.333333
# 2019    247101.083333
# 2020    247355.000000
# Name: average_price, dtype: float64

# %% [markdown]
# ## 7. What is the maximum and minimum no of crimes recorded area?

# %%
housing_df.groupby('area').no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
housing_df.groupby('area').no_of_crimes.min().sort_values(ascending = True)
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# ealing                    1871.0
# islington                 1871.0
# croydon                   2031.0
# ...

# %% [markdown]
# ## 8. Show the total count of records of each area, where average price is less than 100000.

# %%
housing_df[housing_df.average_price < 100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# waltham forest           64
# bexley                   64
# lewisham                 62
# havering                 60
# greenwich                59
# south east               59
# croydon                  57
# sutton                   54
# enfield                  54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# hounslow                 41
# lambeth                  41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
